# %%
import networkx as nx
import matplotlib
import algorithmx
import pandas as pd

G = nx.gnp_random_graph(15, 0.3, 135)
# total de vertices e arestas
n_vertices = G.number_of_nodes()
n_arestas = G.number_of_edges()

print('vertices: ', n_vertices, '\narestas: ', n_arestas)
pares = G.edges()
no_1 = []
no_2 = []
for u, v in pares:
    no_1.append(u)
    no_2.append(v)

print(pares)
#for i in range(len(no_1)):
#    print('par', i,':(',no_1[i],',',no_2[i],')')

nx.draw_circular(G, with_labels=True)
nx.write_edgelist(
    G,
    "grafoBase.csv",
    delimiter = ",",
    data = False,
    encoding ='utf-8'
)
# Out:
# vertices:  15
# arestas:  39
# [(0, 6), (0, 7), (0, 9), (0, 13), (1, 3), (1, 4), (1, 5), (1, 6), (1, 7), (1, 10), (1, 14), (2, 5), (2, 10), (3, 4), (3, 5), (3, 12), (3, 13), (3, 14), (4, 8), (4, 9), (4, 10), (4, 11), (4, 13), (5, 7), (5, 8), (5, 11), (6, 10), (6, 11), (7, 9), (7, 11), (8, 10), (8, 11), (8, 14), (9, 13), (9, 14), (10, 13), (11, 12), (11, 13), (12, 14)]
# par 0 :( 0 , 6 )
# par 1 :( 0 , 7 )
# par 2 :( 0 , 9 )
# par 3 :( 0 , 13 )
# par 4 :( 1 , 3 )
# par 5 :( 1 , 4 )
# par 6 :( 1 , 5 )
# par 7 :( 1 , 6 )
# par 8 :( 1 , 7 )
# par 9 :( 1 , 10 )
# par 10 :( 1 , 14 )
# par 11 :( 2 , 5 )
# par 12 :( 2 , 10 )
# par 13 :( 3 , 4 )
# par 14 :( 3 , 5 )
# par 15 :( 3 , 12 )
# par 16 :( 3 , 13 )
# par 17 :( 3 , 14 )
# par 18 :( 4 , 8 )
# par 19 :( 4 , 9 )
# par 20 :( 4 , 10 )
# par 21 :( 4 , 11 )
# par 22 :( 4 , 13 )
# par 23 :( 5 , 7 )
# par 24 :( 5 , 8 )
# par 25 :( 5 , 11 )
# par 26 :( 6 , 10 )
# par 27 :( 6 , 11 )
# par 28 :( 7 , 9 )
# par 29 :( 7 , 11 )
# par 30 :( 8 , 10 )
# par 31 :( 8 , 11 )
# par 32 :( 8 , 14 )
# par 33 :( 9 , 13 )
# par 34 :( 9 , 14 )
# par 35 :( 10 , 13 )
# par 36 :( 11 , 12 )
# par 37 :( 11 , 13 )
# par 38 :( 12 , 14 )

# %%
with open("grafoBase.csv") as f:
    arestas = f.read().splitlines()
node_1 = []
node_2 = []

for i, cont in zip(arestas, range(len(arestas))):
    node_1.append(i.split(',')[0])
    node_2.append(i.split(',')[1])
    

df = pd.DataFrame({'node_1':node_1, 'node_2':node_2})
# Out:
# 6 0
# 7 1
# 9 2
# 1 3
# 3 4
# 4 5
# 5 6
# 6 7
# 7 8
# 1 9
# 1 10
# 5 11
# 1 12
# 4 13
# 5 14
# 1 15
# 1 16
# 1 17
# 8 18
# 9 19
# 1 20
# 1 21
# 1 22
# 7 23
# 8 24
# 1 25
# 1 26
# 1 27
# 9 28
# 1 29
# 1 30
# 1 31
# 1 32
# 1 33
# 1 34
# , 35
# , 36
# , 37
# , 38
